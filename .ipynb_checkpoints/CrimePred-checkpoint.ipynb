# %% [markdown]
# # Crime Prediction
# ## - Author: Frank Serafine
# ---
#
# **GOAL:** Train various time series machine learning models to predict crime activity over a year, given ten years of history.
#
# **SOURCE:** FBI's [Crime Data Explorer](https://crime-data-explorer.fr.cloud.gov/pages/downloads)
#
# **TRIMMED INCIDENT-LEVEL DATA SET:** [Crime_Pred.csv](https://drive.google.com/file/d/1nM8-DCRj2GA8FxOi04btjwks0gxKAQom/view?usp=sharing)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Crime_Pred.csv')
df_altdrop = pd.read_csv('crimepred_altdrop.csv')
df.head()
# Out:
#    Incident ID  Offense ID        Date  Hour  \
# 0     52643345    60268377  2010-07-15  10.0
# 1     52643346    60268378  2010-07-14  16.0
# 2     52643347    60274057  2010-07-15  11.0
# 3     52643348    60276871  2010-07-15  10.0
# 4     52643348    60276871  2010-07-15  10.0
#
#                                        Offense Attempted or Completed  \
# 0  Theft of Motor Vehicle Parts or Accessories                      A
# 1  Theft of Motor Vehicle Parts or Accessories                      C
# 2     Destruction/Damage/Vandalism of Property                      C
# 3                     Theft From Motor Vehicle                      C
# 4                     Theft From Motor Vehicle                      C
#
#    Offender Age Offender Gender Offender Race Offender Bias Weapon  \
# 0           NaN               U       Unknown          None   None
# 1           NaN               U       Unknown          None   None
# 2           NaN               U       Unknown          None   None
# 3           NaN               U       Unknown          None   None
# 4           NaN               U       Unknown          None   None
#
#   Victim Type  Relation to Offender  Victim Age Victim Gender  \
# 0  Individual  Relationship Unknown        40.0             M
# 1  Individual  Relationship Unknown        39.0             F
# 2    Business        Not Applicable         NaN             U
# 3  Individual  Relationship Unknown        38.0             F
# 4    Business        Not Applicable         NaN             U
#
#                  Victim Race
# 0  Black or African American
# 1                      White
# 2                    Unknown
# 3                      White
# 4                    Unknown

# %%
# Percentage of total observations that are null:

df.isna().sum()/df.shape[0]*100

# 4.6% of crime incidents did not have an hour logged.
# 34.6% of crime incidents did not log the age of the offender.
# 27.4% of crime incidents did not have an age listed for the victim, but this does not always indicate an omission:
# Crimes against an institution or against society do not have a specific victim and thus no victim age.
# Out:
# Incident ID                0.000000
# Offense ID                 0.000000
# Date                       0.000000
# Hour                       4.562732
# Offense                    0.000000
# Attempted or Completed     0.000000
# Offender Age              34.568539
# Offender Gender            0.000000
# Offender Race              0.000000
# Offender Bias              0.000000
# Weapon                     0.000000
# Victim Type                0.000000
# Relation to Offender       0.000000
# Victim Age                27.404400
# Victim Gender              0.000000
# Victim Race                0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6319810 entries, 0 to 6319809
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Incident ID             int64
#  1   Offense ID              int64
#  2   Date                    object
#  3   Hour                    float64
#  4   Offense                 object
#  5   Attempted or Completed  object
#  6   Offender Age            float64
#  7   Offender Gender         object
#  8   Offender Race           object
#  9   Offender Bias           object
#  10  Weapon                  object
#  11  Victim Type             object
#  12  Relation to Offender    object
#  13  Victim Age              float64
#  14  Victim Gender           object
#  15  Victim Race             object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 771.5+ MB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
dupe_data = df.duplicated(keep=False)
df.loc[dupe_data, :]
# Out:
#          Incident ID  Offense ID        Date  Hour  \
# 30          52643365    60280691  2010-07-14  17.0
# 31          52643365    60280691  2010-07-14  17.0
# 32          52643365    60280691  2010-07-14  17.0
# 33          52643365    60280691  2010-07-14  17.0
# 34          52643365    60280692  2010-07-14  17.0
# ...              ...         ...         ...   ...
# 6319543    118447058   143631782  2019-10-15  17.0
# 6319545    118447058   143631783  2019-10-15  17.0
# 6319546    118447058   143631783  2019-10-15  17.0
# 6319703    122904943   148700888  2019-11-10  12.0
# 6319704    122904943   148700888  2019-11-10  12.0
#
#                                           Offense Attempted or Completed  \
# 30                                 Simple Assault                      C
# 31                                 Simple Assault                      C
# 32                                 Simple Assault                      C
# 33                                 Simple Assault                      C
# 34       Destruction/Damage/Vandalism of Property                      C
# ...                                           ...                    ...
# 6319543                               Shoplifting                      C
# 6319545   False Pretenses/Swindle/Confidence Game                      C
# 6319546   False Pretenses/Swindle/Confidence Game                      C
# 6319703                             Impersonation                      C
# 6319704                             Impersonation                      C
#
#          Offender Age Offender Gender              Offender Race  \
# 30               17.0               F  Black or African American
# 31               17.0               F  Black or African American
# 32               22.0               M  Black or African American
# 33               22.0               M  Black or African American
# 34               17.0               F  Black or African American
# ...               ...             ...                        ...
# 6319543          19.0               F                      White
# 6319545          19.0               F                      White
# 6319546          19.0               F                      White
# 6319703           NaN               M                      White
# 6319704           NaN               M                      White
#
#         Offender Bias            Weapon Victim Type     Relation to Offender  \
# 30               None  Personal Weapons  Individual  Victim Was Acquaintance
# 31               None  Personal Weapons  Individual  Victim Was Acquaintance
# 32               None  Personal Weapons  Individual  Victim Was Acquaintance
# 33               None  Personal Weapons  Individual  Victim Was Acquaintance
# 34               None              None  Individual  Victim Was Acquaintance
# ...               ...               ...         ...                      ...
# 6319543          None              None    Business           Not Applicable
# 6319545          None              None    Business           Not Applicable
# 6319546          None              None    Business           Not Applicable
# 6319703          None              None  Individual     Relationship Unknown
# 6319704          None              None  Individual     Relationship Unknown
#
#          Victim Age   Victim Gender                Victim Race
# 30             19.0               F  Black or African American
# 31             19.0               F  Black or African American
# 32             19.0               F  Black or African American
# 33             19.0               F  Black or African American
# 34             19.0               F  Black or African American
# ...             ...             ...                        ...
# 6319543         NaN  Not Applicable             Not Applicable
# 6319545         NaN  Not Applicable             Not Applicable
# 6319546         NaN  Not Applicable             Not Applicable
# 6319703        20.0               F                      White
# 6319704        20.0               F                      White
#
# [2534039 rows x 16 columns]

# %%
df.nunique()
# Out:
# Incident ID               3182165
# Offense ID                3400357
# Date                         3652
# Hour                           24
# Offense                        51
# Attempted or Completed          2
# Offender Age                   98
# Offender Gender                 3
# Offender Race                   7
# Offender Bias                  33
# Weapon                         22
# Victim Type                     9
# Relation to Offender           27
# Victim Age                     98
# Victim Gender                   4
# Victim Race                     8
# dtype: int64

# %%
df_altdrop = df_altdrop.drop_duplicates(keep='first')

# %%
df_altdrop.isna().sum()/df.shape[0]*100
# Out:
# Incident ID                0.000000
# Offense ID                 0.000000
# Victim ID                  0.000000
# Offender ID                0.000000
# Date                       0.000000
# Hour                       3.378013
# Offense                    0.000000
# Attempted or Completed     0.000000
# Offender Age              26.928784
# Offender Gender            0.000000
# Offender Race              0.000000
# Offender Bias              0.000000
# Weapon                     0.000000
# Victim Type                0.000000
# Relation to Offender       0.000000
# Victim Age                22.837079
# Victim Gender              0.000000
# Victim Race                0.000000
# dtype: float64

# %%
# from sklearn.preprocessing import OneHotEncoder

# # Instantiate the OneHotEncoder
# ohe = OneHotEncoder()

# # Fit the OneHotEncoder to the  column and transform
# # It expects a 2D array, so we first convert the column into a DataFrame
# offense = pd.DataFrame(df['Offense'])
# encoded = ohe.fit_transform(subcategory)
# encoded
